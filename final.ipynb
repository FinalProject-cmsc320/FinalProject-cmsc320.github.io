# %% [markdown]
# # Comparitive Analysis of Crime in New York and Los Angeles

# %% [markdown]
# The first step is to import any and all required libraries. Here we import folium a library used to create convenient map API and the numpy and pandas library in order to use the numpy and pandas database functions which makes modifying, adjusting, and comparing the datasets much easier.

# %%
import folium
import pandas 
import numpy

# %% [markdown]
# The next step is to import our datasets. We are looking to compare crime in major cities on the east coast vs the west coast. In order to do this we will look at case studies between New York and Los Angelos, the two biggest cities on each coast (by biggest we mean most populated).

# %% [markdown]
# We will start by importing the LA dataset. The crime dataset we are using for LA is provided by the local Los Angeles government for years 2010 to 2019. I have downloaded the csv file and uploaded them to Jupyter notebook so that we can read the file into a pandas data table using the pandas read_csv function.

# %%
la = pandas.read_csv("LA_CrimeData_2010-2019.csv")
la
# Out:
#              DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0          1307355  02/20/2010 12:00:00 AM  02/20/2010 12:00:00 AM      1350
# 1         11401303  09/13/2010 12:00:00 AM  09/12/2010 12:00:00 AM        45
# 2         70309629  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      1515
# 3         90631215  01/05/2010 12:00:00 AM  01/05/2010 12:00:00 AM       150
# 4        100100501  01/03/2010 12:00:00 AM  01/02/2010 12:00:00 AM      2100
# ...            ...                     ...                     ...       ...
# 2060943  190608903  03/28/2019 12:00:00 AM  03/28/2019 12:00:00 AM       400
# 2060944  190715222  08/15/2019 12:00:00 AM  08/14/2019 12:00:00 AM      1810
# 2060945  192004409  01/06/2019 12:00:00 AM  01/06/2019 12:00:00 AM      2100
# 2060946  191716777  10/17/2019 12:00:00 AM  10/16/2019 12:00:00 AM      1800
# 2060947  190805435  02/01/2019 12:00:00 AM  02/01/2019 12:00:00 AM      1615
#
#          AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0           13      Newton         1385         2     900
# 1           14     Pacific         1485         2     740
# 2           13      Newton         1324         2     946
# 3            6   Hollywood          646         2     900
# 4            1     Central          176         1     122
# ...        ...         ...          ...       ...     ...
# 2060943      6   Hollywood          644         1     648
# 2060944      7    Wilshire          701         1     331
# 2060945     20     Olympic         2029         2     930
# 2060946     17  Devonshire         1795         1     420
# 2060947      8     West LA          852         1     330
#
#                                                Crm Cd Desc  ... Status  \
# 0                                 VIOLATION OF COURT ORDER  ...     AA
# 1        VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...     IC
# 2                                OTHER MISCELLANEOUS CRIME  ...     IC
# 3                                 VIOLATION OF COURT ORDER  ...     IC
# 4                                          RAPE, ATTEMPTED  ...     IC
# ...                                                    ...  ...    ...
# 2060943                                              ARSON  ...     IC
# 2060944   THEFT FROM MOTOR VEHICLE - GRAND ($400 AND OVER)  ...     IC
# 2060945             CRIMINAL THREATS - NO WEAPON DISPLAYED  ...     IC
# 2060946    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)  ...     IC
# 2060947                              BURGLARY FROM VEHICLE  ...     IC
#
#           Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0        Adult Arrest    900.0      NaN       NaN      NaN
# 1         Invest Cont    740.0      NaN       NaN      NaN
# 2         Invest Cont    946.0      NaN       NaN      NaN
# 3         Invest Cont    900.0    998.0       NaN      NaN
# 4         Invest Cont    122.0      NaN       NaN      NaN
# ...               ...      ...      ...       ...      ...
# 2060943   Invest Cont    648.0      NaN       NaN      NaN
# 2060944   Invest Cont    331.0      NaN       NaN      NaN
# 2060945   Invest Cont    930.0      NaN       NaN      NaN
# 2060946   Invest Cont    420.0      NaN       NaN      NaN
# 2060947   Invest Cont    330.0      NaN       NaN      NaN
#
#                                          LOCATION  \
# 0          300 E  GAGE                         AV
# 1                 SEPULVEDA                    BL
# 2         1300 E  21ST                         ST
# 3                 CAHUENGA                     BL
# 4                 8TH                          ST
# ...                                           ...
# 2060943   1400 N  LA BREA                      AV
# 2060944           WILLOUGHBY                   AV
# 2060945                                       6TH
# 2060946  17200    NAPA                         ST
# 2060947   1700    BARRY                        AV
#
#                             Cross Street      LAT       LON
# 0                                    NaN  33.9825 -118.2695
# 1        MANCHESTER                   AV  33.9599 -118.3962
# 2                                    NaN  34.0224 -118.2524
# 3        HOLLYWOOD                    BL  34.1016 -118.3295
# 4        SAN PEDRO                    ST  34.0387 -118.2488
# ...                                  ...      ...       ...
# 2060943                              NaN  34.0962 -118.3490
# 2060944  ORLANDO                      AV  34.0871 -118.3732
# 2060945                           VIRGIL  34.0637 -118.2870
# 2060946                              NaN  34.2266 -118.5085
# 2060947                              NaN  34.0420 -118.4531
#
# [2060948 rows x 28 columns]

# %% [markdown]
# Additionally, I downloaded the dataset for New York City crimes from NYPD open data, which shows the data of crimes in New York City from the years 2006 to 2019. I uploaded it to Jupyter notebook in order to be able to read it using the pandas read_csv function into a data table.

# %%
ny = pandas.read_csv("NY_CrimeData_2006-2019.csv")
ny
# Out:
# /var/folders/gf/98wnlby10hj9q8qx27qcwdzw0000gn/T/ipykernel_8760/1748442183.py:1: DtypeWarning: Columns (18,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   ny = pandas.read_csv("NY_CrimeData_2006-2019.csv")
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0         394506329   12/31/2019     17:30:00          NaN          NaN
# 1         968873685   12/29/2019     16:31:00   12/29/2019     16:54:00
# 2         509837549   12/15/2019     18:45:00          NaN          NaN
# 3         352454313   12/28/2019     01:00:00          NaN          NaN
# 4         248803469   09/05/2008     21:41:00          NaN          NaN
# ...             ...          ...          ...          ...          ...
# 7375988   744350707   12/17/2018     03:00:00   12/17/2018     03:05:00
# 7375989   380927470   06/05/2018     23:30:00   06/06/2018     11:00:00
# 7375990   502083804   02/10/2018     08:30:00   02/10/2018     08:45:00
# 7375991   609916130   12/11/2018     07:30:00   12/11/2018     07:50:00
# 7375992   766425924   05/10/2018     11:30:00   05/10/2018     12:00:00
#
#          ADDR_PCT_CD      RPT_DT  KY_CD                        OFNS_DESC  \
# 0               32.0  12/31/2019    118                DANGEROUS WEAPONS
# 1               47.0  12/29/2019    113                          FORGERY
# 2              109.0  12/29/2019    578                    HARRASSMENT 2
# 3               47.0  12/28/2019    126          MISCELLANEOUS PENAL LAW
# 4                NaN  09/05/2008    101  MURDER & NON-NEGL. MANSLAUGHTER
# ...              ...         ...    ...                              ...
# 7375988         47.0  12/17/2018    348         VEHICLE AND TRAFFIC LAWS
# 7375989         43.0  06/07/2018    110   GRAND LARCENY OF MOTOR VEHICLE
# 7375990         42.0  02/10/2018    341                    PETIT LARCENY
# 7375991         32.0  12/11/2018    344     ASSAULT 3 & RELATED OFFENSES
# 7375992        115.0  05/10/2018    341                    PETIT LARCENY
#
#          PD_CD  ... SUSP_SEX TRANSIT_DISTRICT   Latitude  Longitude  \
# 0        793.0  ...      NaN              NaN  40.820927 -73.943324
# 1        729.0  ...      NaN              NaN  40.885701 -73.861640
# 2        638.0  ...        M              NaN  40.742281 -73.819824
# 3        117.0  ...        M              NaN  40.875311 -73.847545
# 4          NaN  ...      NaN              NaN  40.698827 -73.938819
# ...        ...  ...      ...              ...        ...        ...
# 7375988  916.0  ...      NaN              NaN  40.887333 -73.847250
# 7375989  450.0  ...        M              NaN  40.827414 -73.877946
# 7375990  339.0  ...        U              NaN  40.834528 -73.903836
# 7375991  101.0  ...        U              NaN  40.811812 -73.938329
# 7375992  339.0  ...      NaN              NaN  40.755616 -73.884903
#
#                                           Lat_Lon               PATROL_BORO  \
# 0         (40.82092679700002, -73.94332421899996)     PATROL BORO MAN NORTH
# 1        (40.885701406000074, -73.86164032499995)         PATROL BORO BRONX
# 2               (40.74228115600005, -73.81982408)  PATROL BORO QUEENS NORTH
# 3         (40.87531145100007, -73.84754521099995)         PATROL BORO BRONX
# 4                   (40.698827283, -73.938819047)                       NaN
# ...                                           ...                       ...
# 7375988             (40.887332818, -73.847250013)         PATROL BORO BRONX
# 7375989             (40.827414051, -73.877945775)         PATROL BORO BRONX
# 7375990             (40.834528146, -73.903836069)         PATROL BORO BRONX
# 7375991              (40.81181176, -73.938328651)     PATROL BORO MAN NORTH
# 7375992             (40.755616236, -73.884902833)  PATROL BORO QUEENS NORTH
#
#         STATION_NAME  VIC_AGE_GROUP        VIC_RACE VIC_SEX
# 0                NaN        UNKNOWN         UNKNOWN       E
# 1                NaN        UNKNOWN         UNKNOWN       E
# 2                NaN          25-44  WHITE HISPANIC       F
# 3                NaN        UNKNOWN         UNKNOWN       E
# 4                NaN          25-44           BLACK       M
# ...              ...            ...             ...     ...
# 7375988          NaN          25-44  WHITE HISPANIC       F
# 7375989          NaN          25-44           BLACK       M
# 7375990          NaN          45-64           BLACK       F
# 7375991          NaN            <18           BLACK       M
# 7375992          NaN          25-44  WHITE HISPANIC       F
#
# [7375993 rows x 35 columns]

# %% [markdown]
# Now we want to clean up the database so that we are only looking at data from the years 2010 to 2019 since our more restricted data set (the LA dataset) only has dates from 2010-2019. This way we will be comparing data from both sides of the coast during the same time period.
#
# Let's start with LA. Although the data provided is from 2010-2019, we will run through the process of cleaning the dates for future use and in order to be extra careful.
# Here we run into one issue: the date and time are grouped into one column. We will split this column into day and month, year, and time.

# %% [markdown]
# Here we are parsing the column in the LA dataset using the str.split function and appending the time and whether it occured in the AM or PM together into a new time column in the database.

# %%
la['TIME']=(la['DATE OCC'].str.split().str[1])+(la['DATE OCC'].str.split().str[2])
la['TIME']
# Out:
# 0          12:00:00AM
# 1          12:00:00AM
# 2          12:00:00AM
# 3          12:00:00AM
# 4          12:00:00AM
#               ...
# 2060943    12:00:00AM
# 2060944    12:00:00AM
# 2060945    12:00:00AM
# 2060946    12:00:00AM
# 2060947    12:00:00AM
# Name: TIME, Length: 2060948, dtype: object

# %% [markdown]
# Now we will parse the same original LA dataset data-and-time column to create a new column for the date again using the str.split function.

# %%
la['DATE']=(la['DATE OCC'].str.split().str[0])
la['DATE']
# Out:
# 0          02/20/2010
# 1          09/12/2010
# 2          08/09/2010
# 3          01/05/2010
# 4          01/02/2010
#               ...
# 2060943    03/28/2019
# 2060944    08/14/2019
# 2060945    01/06/2019
# 2060946    10/16/2019
# 2060947    02/01/2019
# Name: DATE, Length: 2060948, dtype: object

# %% [markdown]
# In order to make our life easier, we will create a column to only hold the year, so that we can easily check to see which rows we would want to drop in order to only have data for 2010-2019. We use the str.split function to isolate the year and the astype function to change the year from being stored as a string to being stored as an int.

# %%
la['YEAR']=la['DATE'].str.split('/').str[2]
la['YEAR']=la['YEAR'].astype(int)

la['YEAR']
# Out:
# 0          2010
# 1          2010
# 2          2010
# 3          2010
# 4          2010
#            ...
# 2060943    2019
# 2060944    2019
# 2060945    2019
# 2060946    2019
# 2060947    2019
# Name: YEAR, Length: 2060948, dtype: int64

# %%
la.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA   \
# 0    1307355  02/20/2010 12:00:00 AM  02/20/2010 12:00:00 AM      1350     13
# 1   11401303  09/13/2010 12:00:00 AM  09/12/2010 12:00:00 AM        45     14
# 2   70309629  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      1515     13
# 3   90631215  01/05/2010 12:00:00 AM  01/05/2010 12:00:00 AM       150      6
# 4  100100501  01/03/2010 12:00:00 AM  01/02/2010 12:00:00 AM      2100      1
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0     Newton         1385         2     900
# 1    Pacific         1485         2     740
# 2     Newton         1324         2     946
# 3  Hollywood          646         2     900
# 4    Central          176         1     122
#
#                                          Crm Cd Desc  ... Crm Cd 2  Crm Cd 3  \
# 0                           VIOLATION OF COURT ORDER  ...      NaN       NaN
# 1  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...      NaN       NaN
# 2                          OTHER MISCELLANEOUS CRIME  ...      NaN       NaN
# 3                           VIOLATION OF COURT ORDER  ...    998.0       NaN
# 4                                    RAPE, ATTEMPTED  ...      NaN       NaN
#
#   Crm Cd 4                                 LOCATION  \
# 0      NaN   300 E  GAGE                         AV
# 1      NaN          SEPULVEDA                    BL
# 2      NaN  1300 E  21ST                         ST
# 3      NaN          CAHUENGA                     BL
# 4      NaN          8TH                          ST
#
#                       Cross Street      LAT       LON        TIME        DATE  \
# 0                              NaN  33.9825 -118.2695  12:00:00AM  02/20/2010
# 1  MANCHESTER                   AV  33.9599 -118.3962  12:00:00AM  09/12/2010
# 2                              NaN  34.0224 -118.2524  12:00:00AM  08/09/2010
# 3  HOLLYWOOD                    BL  34.1016 -118.3295  12:00:00AM  01/05/2010
# 4  SAN PEDRO                    ST  34.0387 -118.2488  12:00:00AM  01/02/2010
#
#    YEAR
# 0  2010
# 1  2010
# 2  2010
# 3  2010
# 4  2010
#
# [5 rows x 31 columns]

# %% [markdown]
#  Now that we have the columns for date and time parsed, we can remove all rows that do not fall under the year 2010-2019.

# %%
la = la[la['YEAR'] >= 2010]
la = la[la['YEAR']<=2019]
la
# Out:
#              DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 133309   112007247  02/28/2011 12:00:00 AM  02/27/2011 12:00:00 AM      1600
# 133367   111312424  05/18/2011 12:00:00 AM  05/17/2011 12:00:00 AM      1630
# 133423   111920575  10/06/2011 12:00:00 AM  10/05/2011 12:00:00 AM      2030
# 209175   111722147  12/25/2011 12:00:00 AM  12/25/2011 12:00:00 AM      1030
# 209216   110706802  03/08/2011 12:00:00 AM  03/07/2011 12:00:00 AM      1200
# ...            ...                     ...                     ...       ...
# 1843176  181804617  01/11/2018 12:00:00 AM  01/06/2018 12:00:00 AM       100
# 1843177  180708032  03/26/2018 12:00:00 AM  03/23/2018 12:00:00 AM      1000
# 1843178  181109895  05/03/2018 12:00:00 AM  03/23/2018 12:00:00 AM      1200
# 1843179  181108488  04/06/2018 12:00:00 AM  02/24/2018 12:00:00 AM       130
# 1843180  181011293  06/09/2018 12:00:00 AM  06/02/2018 12:00:00 AM      2130
#
#          AREA     AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 133309      20      Olympic         2022         1     510
# 133367      13       Newton         1373         1     510
# 133423      19      Mission         1999         1     510
# 209175      17   Devonshire         1707         1     310
# 209216       7     Wilshire          701         1     331
# ...        ...          ...          ...       ...     ...
# 1843176     18    Southeast         1844         1     440
# 1843177      7     Wilshire          713         1     442
# 1843178     11    Northeast         1113         2     649
# 1843179     11    Northeast         1135         2     860
# 1843180     10  West Valley         1043         1     330
#
#                                               Crm Cd Desc  ... Crm Cd 2  \
# 133309                                   VEHICLE - STOLEN  ...      NaN
# 133367                                   VEHICLE - STOLEN  ...      NaN
# 133423                                   VEHICLE - STOLEN  ...      NaN
# 209175                                           BURGLARY  ...      NaN
# 209216   THEFT FROM MOTOR VEHICLE - GRAND ($400 AND OVER)  ...      NaN
# ...                                                   ...  ...      ...
# 1843176                THEFT PLAIN - PETTY ($950 & UNDER)  ...      NaN
# 1843177          SHOPLIFTING - PETTY THEFT ($950 & UNDER)  ...      NaN
# 1843178                  DOCUMENT FORGERY / STOLEN FELONY  ...      NaN
# 1843179                       BATTERY WITH SEXUAL CONTACT  ...      NaN
# 1843180                             BURGLARY FROM VEHICLE  ...      NaN
#
#          Crm Cd 3 Crm Cd 4                                  LOCATION  \
# 133309        NaN      NaN    500 S  SAINT ANDREWS                PL
# 133367        NaN      NaN    600 E  55TH                         ST
# 133423        NaN      NaN   8100    GREENBUSH                    AV
# 209175        NaN      NaN  17000    WESTBURY                     DR
# 209216        NaN      NaN    600 N  KILKEA                       DR
# ...           ...      ...                                       ...
# 1843176       NaN      NaN    400 E  IMPERIAL                     HY
# 1843177       NaN      NaN    400 N  FAIRFAX                      AV
# 1843178       NaN      NaN   2400    COLORADO                     BL
# 1843179       NaN      NaN   3900    RODERICK                     RD
# 1843180       NaN      NaN   5600    YOLANDA                      AV
#
#          Cross Street      LAT       LON        TIME        DATE  YEAR
# 133309            NaN  34.0654 -118.3116  12:00:00AM  02/27/2011  2011
# 133367            NaN  33.9925 -118.2652  12:00:00AM  05/17/2011  2011
# 133423            NaN  34.2177 -118.4267  12:00:00AM  10/05/2011  2011
# 209175            NaN  34.2990 -118.5027  12:00:00AM  12/25/2011  2011
# 209216            NaN  34.0816 -118.3669  12:00:00AM  03/07/2011  2011
# ...               ...      ...       ...         ...         ...   ...
# 1843176           NaN  33.9345 -118.2623  12:00:00AM  01/06/2018  2018
# 1843177           NaN  34.0782 -118.3614  12:00:00AM  03/23/2018  2018
# 1843178           NaN  34.1400 -118.2190  12:00:00AM  03/23/2018  2018
# 1843179           NaN  34.1208 -118.2320  12:00:00AM  02/24/2018  2018
# 1843180           NaN  34.1787 -118.5407  12:00:00AM  06/02/2018  2018
#
# [1406556 rows x 31 columns]

# %% [markdown]
# Now we will repeat this process for the NYC database, specifically on the from date and time. We are not concerned about the duration of the crime.
# Additionally, we will relabel the time and date columns so that it mirrors that of the la database.

# %%
ny
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0         394506329   12/31/2019     17:30:00          NaN          NaN
# 1         968873685   12/29/2019     16:31:00   12/29/2019     16:54:00
# 2         509837549   12/15/2019     18:45:00          NaN          NaN
# 3         352454313   12/28/2019     01:00:00          NaN          NaN
# 4         248803469   09/05/2008     21:41:00          NaN          NaN
# ...             ...          ...          ...          ...          ...
# 7375988   744350707   12/17/2018     03:00:00   12/17/2018     03:05:00
# 7375989   380927470   06/05/2018     23:30:00   06/06/2018     11:00:00
# 7375990   502083804   02/10/2018     08:30:00   02/10/2018     08:45:00
# 7375991   609916130   12/11/2018     07:30:00   12/11/2018     07:50:00
# 7375992   766425924   05/10/2018     11:30:00   05/10/2018     12:00:00
#
#          ADDR_PCT_CD      RPT_DT  KY_CD                        OFNS_DESC  \
# 0               32.0  12/31/2019    118                DANGEROUS WEAPONS
# 1               47.0  12/29/2019    113                          FORGERY
# 2              109.0  12/29/2019    578                    HARRASSMENT 2
# 3               47.0  12/28/2019    126          MISCELLANEOUS PENAL LAW
# 4                NaN  09/05/2008    101  MURDER & NON-NEGL. MANSLAUGHTER
# ...              ...         ...    ...                              ...
# 7375988         47.0  12/17/2018    348         VEHICLE AND TRAFFIC LAWS
# 7375989         43.0  06/07/2018    110   GRAND LARCENY OF MOTOR VEHICLE
# 7375990         42.0  02/10/2018    341                    PETIT LARCENY
# 7375991         32.0  12/11/2018    344     ASSAULT 3 & RELATED OFFENSES
# 7375992        115.0  05/10/2018    341                    PETIT LARCENY
#
#          PD_CD  ... SUSP_SEX TRANSIT_DISTRICT   Latitude  Longitude  \
# 0        793.0  ...      NaN              NaN  40.820927 -73.943324
# 1        729.0  ...      NaN              NaN  40.885701 -73.861640
# 2        638.0  ...        M              NaN  40.742281 -73.819824
# 3        117.0  ...        M              NaN  40.875311 -73.847545
# 4          NaN  ...      NaN              NaN  40.698827 -73.938819
# ...        ...  ...      ...              ...        ...        ...
# 7375988  916.0  ...      NaN              NaN  40.887333 -73.847250
# 7375989  450.0  ...        M              NaN  40.827414 -73.877946
# 7375990  339.0  ...        U              NaN  40.834528 -73.903836
# 7375991  101.0  ...        U              NaN  40.811812 -73.938329
# 7375992  339.0  ...      NaN              NaN  40.755616 -73.884903
#
#                                           Lat_Lon               PATROL_BORO  \
# 0         (40.82092679700002, -73.94332421899996)     PATROL BORO MAN NORTH
# 1        (40.885701406000074, -73.86164032499995)         PATROL BORO BRONX
# 2               (40.74228115600005, -73.81982408)  PATROL BORO QUEENS NORTH
# 3         (40.87531145100007, -73.84754521099995)         PATROL BORO BRONX
# 4                   (40.698827283, -73.938819047)                       NaN
# ...                                           ...                       ...
# 7375988             (40.887332818, -73.847250013)         PATROL BORO BRONX
# 7375989             (40.827414051, -73.877945775)         PATROL BORO BRONX
# 7375990             (40.834528146, -73.903836069)         PATROL BORO BRONX
# 7375991              (40.81181176, -73.938328651)     PATROL BORO MAN NORTH
# 7375992             (40.755616236, -73.884902833)  PATROL BORO QUEENS NORTH
#
#         STATION_NAME  VIC_AGE_GROUP        VIC_RACE VIC_SEX
# 0                NaN        UNKNOWN         UNKNOWN       E
# 1                NaN        UNKNOWN         UNKNOWN       E
# 2                NaN          25-44  WHITE HISPANIC       F
# 3                NaN        UNKNOWN         UNKNOWN       E
# 4                NaN          25-44           BLACK       M
# ...              ...            ...             ...     ...
# 7375988          NaN          25-44  WHITE HISPANIC       F
# 7375989          NaN          25-44           BLACK       M
# 7375990          NaN          45-64           BLACK       F
# 7375991          NaN            <18           BLACK       M
# 7375992          NaN          25-44  WHITE HISPANIC       F
#
# [7375993 rows x 35 columns]

# %%
#Here we are renaming the time column. 
ny['TIME']= ny['CMPLNT_FR_TM']
ny['TIME']
# Out:
# 0          17:30:00
# 1          16:31:00
# 2          18:45:00
# 3          01:00:00
# 4          21:41:00
#              ...
# 7375988    03:00:00
# 7375989    23:30:00
# 7375990    08:30:00
# 7375991    07:30:00
# 7375992    11:30:00
# Name: TIME, Length: 7375993, dtype: object

# %%
ny['DATE']=(ny['CMPLNT_FR_DT'].str.split().str[0])
ny['DATE']
# Out:
# 0          12/31/2019
# 1          12/29/2019
# 2          12/15/2019
# 3          12/28/2019
# 4          09/05/2008
#               ...
# 7375988    12/17/2018
# 7375989    06/05/2018
# 7375990    02/10/2018
# 7375991    12/11/2018
# 7375992    05/10/2018
# Name: DATE, Length: 7375993, dtype: object

# %% [markdown]
# Before we can continue with parsing the date data, we have to decide how we want to deal with missing date and time data. Because the dataset lacks context for us to be able to make a hypothesis about whem the missing crimes were committed and it doesn't make sense to assign an average date and time, we will remove the rows with missing date and time values. (Note: we did not run into this issue in the LA dataset because we were not missing and date and/or time data.

# %%
ny=ny[ny['YEAR']!='NaN']
ny['YEAR']=ny['DATE'].str.split('/').str[2]
ny['YEAR']=ny['YEAR'].astype(int)

ny = ny[ny['YEAR'] >= 2010]
#ny = ny[ny['YEAR']<=2019]
ny.sort_values(by=['YEAR'])
ny
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0         394506329   12/31/2019     17:30:00          NaN          NaN
# 1         968873685   12/29/2019     16:31:00   12/29/2019     16:54:00
# 2         509837549   12/15/2019     18:45:00          NaN          NaN
# 3         352454313   12/28/2019     01:00:00          NaN          NaN
# 5         293718737   12/27/2019     22:00:00          NaN          NaN
# ...             ...          ...          ...          ...          ...
# 7375988   744350707   12/17/2018     03:00:00   12/17/2018     03:05:00
# 7375989   380927470   06/05/2018     23:30:00   06/06/2018     11:00:00
# 7375990   502083804   02/10/2018     08:30:00   02/10/2018     08:45:00
# 7375991   609916130   12/11/2018     07:30:00   12/11/2018     07:50:00
# 7375992   766425924   05/10/2018     11:30:00   05/10/2018     12:00:00
#
#          ADDR_PCT_CD      RPT_DT  KY_CD                       OFNS_DESC  \
# 0               32.0  12/31/2019    118               DANGEROUS WEAPONS
# 1               47.0  12/29/2019    113                         FORGERY
# 2              109.0  12/29/2019    578                   HARRASSMENT 2
# 3               47.0  12/28/2019    126         MISCELLANEOUS PENAL LAW
# 5                9.0  12/27/2019    107                        BURGLARY
# ...              ...         ...    ...                             ...
# 7375988         47.0  12/17/2018    348        VEHICLE AND TRAFFIC LAWS
# 7375989         43.0  06/07/2018    110  GRAND LARCENY OF MOTOR VEHICLE
# 7375990         42.0  02/10/2018    341                   PETIT LARCENY
# 7375991         32.0  12/11/2018    344    ASSAULT 3 & RELATED OFFENSES
# 7375992        115.0  05/10/2018    341                   PETIT LARCENY
#
#          PD_CD  ...  Longitude                                   Lat_Lon  \
# 0        793.0  ... -73.943324   (40.82092679700002, -73.94332421899996)
# 1        729.0  ... -73.861640  (40.885701406000074, -73.86164032499995)
# 2        638.0  ... -73.819824         (40.74228115600005, -73.81982408)
# 3        117.0  ... -73.847545   (40.87531145100007, -73.84754521099995)
# 5        223.0  ... -73.980466   (40.72075882100006, -73.98046642299995)
# ...        ...  ...        ...                                       ...
# 7375988  916.0  ... -73.847250             (40.887332818, -73.847250013)
# 7375989  450.0  ... -73.877946             (40.827414051, -73.877945775)
# 7375990  339.0  ... -73.903836             (40.834528146, -73.903836069)
# 7375991  101.0  ... -73.938329              (40.81181176, -73.938328651)
# 7375992  339.0  ... -73.884903             (40.755616236, -73.884902833)
#
#                       PATROL_BORO STATION_NAME VIC_AGE_GROUP        VIC_RACE  \
# 0           PATROL BORO MAN NORTH          NaN       UNKNOWN         UNKNOWN
# 1               PATROL BORO BRONX          NaN       UNKNOWN         UNKNOWN
# 2        PATROL BORO QUEENS NORTH          NaN         25-44  WHITE HISPANIC
# 3               PATROL BORO BRONX          NaN       UNKNOWN         UNKNOWN
# 5           PATROL BORO MAN SOUTH          NaN       UNKNOWN         UNKNOWN
# ...                           ...          ...           ...             ...
# 7375988         PATROL BORO BRONX          NaN         25-44  WHITE HISPANIC
# 7375989         PATROL BORO BRONX          NaN         25-44           BLACK
# 7375990         PATROL BORO BRONX          NaN         45-64           BLACK
# 7375991     PATROL BORO MAN NORTH          NaN           <18           BLACK
# 7375992  PATROL BORO QUEENS NORTH          NaN         25-44  WHITE HISPANIC
#
#         VIC_SEX      TIME        DATE  YEAR
# 0             E  17:30:00  12/31/2019  2019
# 1             E  16:31:00  12/29/2019  2019
# 2             F  18:45:00  12/15/2019  2019
# 3             E  01:00:00  12/28/2019  2019
# 5             M  22:00:00  12/27/2019  2019
# ...         ...       ...         ...   ...
# 7375988       F  03:00:00  12/17/2018  2018
# 7375989       M  23:30:00  06/05/2018  2018
# 7375990       F  08:30:00  02/10/2018  2018
# 7375991       M  07:30:00  12/11/2018  2018
# 7375992       F  11:30:00  05/10/2018  2018
#
# [4335761 rows x 38 columns]
